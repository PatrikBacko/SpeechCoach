# %%
# !pip install -q kokoro>=0.9.2 soundfile
# !apt-get -qq -y install espeak-ng > /dev/null 2>&1

# %%
from kokoro import KPipeline
from IPython.display import display, Audio
import soundfile as sf
import torch
pipeline = KPipeline(
    lang_code='a',
    repo_id='hexgrad/Kokoro-82M'
)
text = 'Hello, this is a test of text to speech synthesis system.'
voice_en = 'af_heart'
voice_gb = 'bf_isabella'

generator = pipeline(text, voice=voice_en)
for i, (gs, ps, audio) in enumerate(generator):
    print(i, gs, ps)
    display(Audio(data=audio, rate=24000, autoplay=i==0))
    sf.write(f'{i}.wav', audio, 24000)
# Out:
# 0 Hello, this is a test of text to speech synthesis system. həlˈO, ðɪs ɪz ɐ tˈɛst ʌv tˈɛkst tə spˈiʧ sˈɪnθəsɪs sˈɪstəm.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pipeline.voices.keys()
# Out:
# dict_keys(['bf_isabella'])

# %%
for v in generator:
    x = v
# Out:
# tensor([-3.7200e-07,  1.5361e-07, -6.8360e-08,  ..., -1.7541e-08,
#          1.8688e-08, -2.0364e-08])

# %%
x.audio.detach().cpu().numpy()
# Out:
# array([-3.7199760e-07,  1.5360834e-07, -6.8360137e-08, ...,
#        -1.7541218e-08,  1.8687652e-08, -2.0364325e-08],
#       shape=(103800,), dtype=float32)
